# %%
# %load ./locate_db_cycles.py
import os 
from collections import defaultdict
import networkx as nx

data_dir = '../output'

# setting a kmer size value 
k = 20 

# instantiating kmer_ids  
kmer_ids = {}
kmer_num = 0

# instantiating the digraph
db_graph = nx.DiGraph()

print('Constructing the de Bruijn graph.')
# adding di bruijn edges to graph 
seqs_fn = os.path.join(data_dir, 'SRR7225827.seqs')
with open(seqs_fn) as f: 
    for line_num, line in enumerate(f):
        line = line.strip()
    
        #if line_num % 1000000 == 0:
        if (line_num + 1) % 10000 == 0:
            print('\tProcessing line number: {}'.format(line_num))
            break
        
        for i in range(len(line) - k):
            
            # get the first kmer
            first_kmer = line[i: i + k]
            
            # get the id of the first kmer 
            if first_kmer not in kmer_ids: 
                kmer_ids[kmer_num] = first_kmer
                kmer_num += 1
                first_id = kmer_ids[first_kmer]
            else:
                first_id = kmer_ids[first_kmer]

            # get the second kmer
            second_kmer = line[i + 1: i + k + 1]

            # get the id of the second kmer 
            if second_kmer not in kmer_ids: 
                kmer_ids[second_kmer] = kmer_num 
                kmer_num += 1
                second_id = kmer_ids[second_kmer]
            else:
                second_id = kmer_ids[second_kmer]

            db_graph.add_edge(first_id, second_id)
# Out:
# Constructing the de Bruijn graph.
# 	Processing line number: 9999

# %%
# locating all cycles in the graph 
print('Locating all cycles in the graph.')
cycles = nx.simple_cycles(db_graph)
# Out:
# Locating all cycles in the graph.

# %%
# removing self-loops
print('Removing self-loops.')
cycles = [cycle for cycle in cycles if len(cycle) > 1]
# Out:
# Removing self-loops.

# %%
# writing all the cycles in the graph 
print('Writing all the cycles in the graph.')
cycles_fn = os.path.join(data_dir, 'SRR7225827.cycles.txt')
with open(cycles_fn, 'w') as f: 
    
    # writing all other cycles
    for cycle in cycles:

        # adding the very first node of cycle to a reformatted cycle 
        re_cycle = kmer_ids[cycle[0]]
        for node in cycle[1:]: 
            node_seq = kmer_ids[node]
            re_cycle += node_seq[-1]
        
        # calculating the length of the cycle
        cycle_len = len(re_cycle)

        # saving the cycle with its length 
        f.write('{}\t{}\n'.format(re_cycle, cycle_len))
# Out:
# Writing all the cycles in the graph.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-c4062c4fa0ae> in <module>
#       8
#       9         # adding the very first node of cycle to a reformatted cycle
# ---> 10         re_cycle = kmer_ids[cycle[0]]
#      11         for node in cycle[1:]:
#      12             node_seq = kmer_ids[node]
#
# KeyError: 130272

# %%
kmer_ids
# Out:
# {'GTGTAGAGGGAAGGTTAATG': 0,
#  'TGTAGAGGGAAGGTTAATGG': 1,
#  'GTAGAGGGAAGGTTAATGGT': 2,
#  'TAGAGGGAAGGTTAATGGTT': 3,
#  'AGAGGGAAGGTTAATGGTTG': 4,
#  'GAGGGAAGGTTAATGGTTGA': 5,
#  'AGGGAAGGTTAATGGTTGAT': 6,
#  'GGGAAGGTTAATGGTTGATA': 7,
#  'GGAAGGTTAATGGTTGATAT': 8,
#  'GAAGGTTAATGGTTGATATT': 9,
#  'AAGGTTAATGGTTGATATTG': 10,
#  'AGGTTAATGGTTGATATTGC': 11,
#  'GGTTAATGGTTGATATTGCT': 12,
#  'GTTAATGGTTGATATTGCTA': 13,
#  'TTAATGGTTGATATTGCTAG': 14,
#  'TAATGGTTGATATTGCTAGG': 15,
#  'AATGGTTGATATTGCTAGGG': 16,
#  'ATGGTTGATATTGCTAGGGT': 17,
#  'TGGTTGATATTGCTAGGGTG': 18,
#  'GGTTGATATTGCTAGGGTGG': 19,
#  'GTTGATATTGCTAGGGTGGC': 20,
#  'TTGATATTGCTAGGGTGGCG': 21,
#  'TGATATTGCTAGGGTGGCGC': 22,
#  'GATATTGCTAGGGTGGCGCT': 23,
#  'ATATTGCTAGGGTGGCGCTT': 24,
#  'TATTGCTAGGGTGGCGCTTC': 25,
#  'ATTGCTAGGGTGGCGCTTCC': 26,
#  'TTGCTAGGGTGGCGCTTCCA': 27,
#  'TGCTAGGGTGGCGCTTCCAA': 28,
#  'GCTAGGGTGGCGCTTCCAAT': 29,
#  'CTAGGGTGGCGCTTCCAATT': 30,
#  'NCTATAGGCGCTTGTCAGGG': 31,
#  'CTATAGGCGCTTGTCAGGGA': 32,
#  'TATAGGCGCTTGTCAGGGAG': 33,
#  'ATAGGCGCTTGTCAGGGAGG': 34,
#  'TAGGCGCTTGTCAGGGAGGT': 35,
#  'AGGCGCTTGTCAGGGAGGTA': 36,
#  'GGCGCTTGTCAGGGAGGTAG': 37,
#  'GCGCTTGTCAGGGAGGTAGC': 38,
#  'CGCTTGTCAGGGAGGTAGCG': 39,
#  'GCTTGTCAGGGAGGTAGCGA': 40,
#  'CTTGTCAGGGAGGTAGCGAT': 41,
#  'TTGTCAGGGAGGTAGCGATG': 42,
#  'TGTCAGGGAGGTAGCGATGA': 43,
#  'GTCAGGGAGGTAGCGATGAG': 44,
#  'TCAGGGAGGTAGCGATGAGA': 45,
#  'CAGGGAGGTAGCGATGAGAG': 46,
#  'AGGGAGGTAGCGATGAGAGT': 47,
#  'GGGAGGTAGCGATGAGAGTA': 48,
#  'GGAGGTAGCGATGAGAGTAA': 49,
#  'GAGGTAGCGATGAGAGTAAT': 50,
#  'AGGTAGCGATGAGAGTAATA': 51,
#  'GGTAGCGATGAGAGTAATAG': 52,
#  'GTAGCGATGAGAGTAATAGA': 53,
#  'TAGCGATGAGAGTAATAGAT': 54,
#  'AGCGATGAGAGTAATAGATA': 55,
#  'GCGATGAGAGTAATAGATAG': 56,
#  'CGATGAGAGTAATAGATAGG': 57,
#  'GATGAGAGTAATAGATAGGG': 58,
#  'ATGAGAGTAATAGATAGGGC': 59,
#  'TGAGAGTAATAGATAGGGCT': 60,
#  'GAGAGTAATAGATAGGGCTC': 61,
#  'GTTGAGGTCTAGGGCTGTTA': 62,
#  'TTGAGGTCTAGGGCTGTTAG': 63,
#  'TGAGGTCTAGGGCTGTTAGA': 64,
#  'GAGGTCTAGGGCTGTTAGAA': 65,
#  'AGGTCTAGGGCTGTTAGAAG': 66,
#  'GGTCTAGGGCTGTTAGAAGT': 67,
#  'GTCTAGGGCTGTTAGAAGTC': 68,
#  'TCTAGGGCTGTTAGAAGTCC': 69,
#  'CTAGGGCTGTTAGAAGTCCT': 70,
#  'TAGGGCTGTTAGAAGTCCTA': 71,
#  'AGGGCTGTTAGAAGTCCTAG': 72,
#  'GGGCTGTTAGAAGTCCTAGG': 73,
#  'GGCTGTTAGAAGTCCTAGGA': 74,
#  'GCTGTTAGAAGTCCTAGGAA': 75,
#  'CTGTTAGAAGTCCTAGGAAA': 76,
#  'TGTTAGAAGTCCTAGGAAAG': 77,
#  'GTTAGAAGTCCTAGGAAAGT': 78,
#  'TTAGAAGTCCTAGGAAAGTG': 79,
#  'TAGAAGTCCTAGGAAAGTGA': 80,
#  'AGAAGTCCTAGGAAAGTGAC': 81,
#  'GAAGTCCTAGGAAAGTGACA': 82,
#  'AAGTCCTAGGAAAGTGACAG': 83,
#  'AGTCCTAGGAAAGTGACAGC': 84,
#  'GTCCTAGGAAAGTGACAGCG': 85,
#  'TCCTAGGAAAGTGACAGCGA': 86,
#  'CCTAGGAAAGTGACAGCGAG': 87,
#  'CTAGGAAAGTGACAGCGAGG': 88,
#  'TAGGAAAGTGACAGCGAGGG': 89,
#  'AGGAAAGTGACAGCGAGGGC': 90,
#  'GGAAAGTGACAGCGAGGGCT': 91,
#  'GAAAGTGACAGCGAGGGCTG': 92,
#  'GGGTATGGGGTTAGCAGCGG': 93,
#  'GGTATGGGGTTAGCAGCGGT': 94,
#  'GTATGGGGTTAGCAGCGGTG': 95,
#  'TATGGGGTTAGCAGCGGTGT': 96,
#  'ATGGGGTTAGCAGCGGTGTG': 97,
#  'TGGGGTTAGCAGCGGTGTGT': 98,
#  'GGGGTTAGCAGCGGTGTGTG': 99,
#  'GGGTTAGCAGCGGTGTGTGT': 100,
#  'GGTTAGCAGCGGTGTGTGTG': 101,
#  'GTTAGCAGCGGTGTGTGTGT': 102,
#  'TTAGCAGCGGTGTGTGTGTG': 103,
#  'TAGCAGCGGTGTGTGTGTGC': 104,
#  'AGCAGCGGTGTGTGTGTGCT': 105,
#  'GCAGCGGTGTGTGTGTGCTG': 106,
#  'CAGCGGTGTGTGTGTGCTGG': 107,
#  'AGCGGTGTGTGTGTGCTGGG': 108,
#  'GCGGTGTGTGTGTGCTGGGT': 109,
#  'CGGTGTGTGTGTGCTGGGTA': 110,
#  'GGTGTGTGTGTGCTGGGTAG': 111,
#  'GTGTGTGTGTGCTGGGTAGG': 112,
#  'TGTGTGTGTGCTGGGTAGGA': 113,
#  'GTGTGTGTGCTGGGTAGGAT': 114,
#  'TGTGTGTGCTGGGTAGGATG': 115,
#  'GTGTGTGCTGGGTAGGATGG': 116,
#  'TGTGTGCTGGGTAGGATGGG': 117,
#  'GTGTGCTGGGTAGGATGGGC': 118,
#  'TGTGCTGGGTAGGATGGGCG': 119,
#  'GTGCTGGGTAGGATGGGCGG': 120,
#  'TGCTGGGTAGGATGGGCGGG': 121,
#  'GCTGGGTAGGATGGGCGGGG': 122,
#  'CTGGGTAGGATGGGCGGGGG': 123,
#  'GAGCGAGGAGAGTAGCACTC': 124,
#  'AGCGAGGAGAGTAGCACTCT': 125,
#  'GCGAGGAGAGTAGCACTCTT': 126,
#  'CGAGGAGAGTAGCACTCTTG': 127,
#  'GAGGAGAGTAGCACTCTTGT': 128,
#  'AGGAGAGTAGCACTCTTGTG': 129,
#  'GGAGAGTAGCACTCTTGTGC': 130,
#  'GAGAGTAGCACTCTTGTGCG': 131,
#  'AGAGTAGCACTCTTGTGCGG': 132,
#  'GAGTAGCACTCTTGTGCGGG': 133,
#  'AGTAGCACTCTTGTGCGGGA': 134,
#  'GTAGCACTCTTGTGCGGGAT': 135,
#  'TAGCACTCTTGTGCGGGATA': 136,
#  'AGCACTCTTGTGCGGGATAT': 137,
#  'GCACTCTTGTGCGGGATATT': 138,
#  'CACTCTTGTGCGGGATATTG': 139,
#  'ACTCTTGTGCGGGATATTGA': 140,
#  'CTCTTGTGCGGGATATTGAT': 141,
#  'TCTTGTGCGGGATATTGATT': 142,
#  'CTTGTGCGGGATATTGATTT': 143,
#  'TTGTGCGGGATATTGATTTC': 144,
#  'TGTGCGGGATATTGATTTCA': 145,
#  'GTGCGGGATATTGATTTCAC': 146,
#  'TGCGGGATATTGATTTCACG': 147,
#  'GCGGGATATTGATTTCACGG': 148,
#  'CGGGATATTGATTTCACGGA': 149,
#  'GGGATATTGATTTCACGGAG': 150,
#  'GGATATTGATTTCACGGAGG': 151,
#  'GATATTGATTTCACGGAGGA': 152,
#  'ATATTGATTTCACGGAGGAT': 153,
#  'TATTGATTTCACGGAGGATG': 154,
#  'CTCCACCTCCTATTCTTGCA': 155,
#  'TCCACCTCCTATTCTTGCAC': 156,
#  'CCACCTCCTATTCTTGCACG': 157,
#  'CACCTCCTATTCTTGCACGA': 158,
#  'ACCTCCTATTCTTGCACGAA': 159,
#  'CCTCCTATTCTTGCACGAAA': 160,
#  'CTCCTATTCTTGCACGAAAC': 161,
#  'TCCTATTCTTGCACGAAACG': 162,
#  'CCTATTCTTGCACGAAACGG': 163,
#  'CTATTCTTGCACGAAACGGG': 164,
#  'TATTCTTGCACGAAACGGGA': 165,
#  'ATTCTTGCACGAAACGGGAT': 166,
#  'TTCTTGCACGAAACGGGATC': 167,
#  'TCTTGCACGAAACGGGATCA': 168,
#  'CTTGCACGAAACGGGATCAA': 169,
#  'TTGCACGAAACGGGATCAAA': 170,
#  'TGCACGAAACGGGATCAAAC': 171,
#  'GCACGAAACGGGATCAAACA': 172,
#  'CACGAAACGGGATCAAACAA': 173,
#  'ACGAAACGGGATCAAACAAC': 174,
#  'CGAAACGGGATCAAACAACC': 175,
#  'GAAACGGGATCAAACAACCC': 176,
#  'AAACGGGATCAAACAACCCC': 177,
#  'AACGGGATCAAACAACCCCC': 178,
#  'ACGGGATCAAACAACCCCCT': 179,
#  'CGGGATCAAACAACCCCCTA': 180,
#  'GGGATCAAACAACCCCCTAG': 181,
#  'GGATCAAACAACCCCCTAGG': 182,
#  'GATCAAACAACCCCCTAGGA': 183,
#  'ATCAAACAACCCCCTAGGAA': 184,
#  'TCAAACAACCCCCTAGGAAT': 185,
#  'AGGGCGGCCTAGCGCCCCTC': 186,
#  'GGGCGGCCTAGCGCCCCTCT': 187,
#  'GGCGGCCTAGCGCCCCTCTG': 188,
#  'GCGGCCTAGCGCCCCTCTGC': 189,
#  'CGGCCTAGCGCCCCTCTGCC': 190,
#  'GGCCTAGCGCCCCTCTGCCG': 191,
#  'GCCTAGCGCCCCTCTGCCGG': 192,
#  'CCTAGCGCCCCTCTGCCGGC': 193,
#  'CTAGCGCCCCTCTGCCGGCC': 194,
#  'TAGCGCCCCTCTGCCGGCCG': 195,
#  'AGCGCCCCTCTGCCGGCCGG': 196,
#  'GCGCCCCTCTGCCGGCCGGT': 197,
#  'CGCCCCTCTGCCGGCCGGTG': 198,
#  'GCCCCTCTGCCGGCCGGTGG': 199,
#  'CCCCTCTGCCGGCCGGTGGT': 200,
#  'CCCTCTGCCGGCCGGTGGTT': 201,
#  'CCTCTGCCGGCCGGTGGTTG': 202,
#  'CTCTGCCGGCCGGTGGTTGG': 203,
#  'TCTGCCGGCCGGTGGTTGGA': 204,
#  'CTGCCGGCCGGTGGTTGGAG': 205,
#  'TGCCGGCCGGTGGTTGGAGG': 206,
#  'GCCGGCCGGTGGTTGGAGGC': 207,
#  'CCGGCCGGTGGTTGGAGGCC': 208,
#  'CGGCCGGTGGTTGGAGGCCG': 209,
#  'GGCCGGTGGTTGGAGGCCGC': 210,
#  'GCCGGTGGTTGGAGGCCGCG': 211,
#  'CCGGTGGTTGGAGGCCGCGG': 212,
#  'CGGTGGTTGGAGGCCGCGGC': 213,
#  'GGTGGTTGGAGGCCGCGGCG': 214,
#  'GTGGTTGGAGGCCGCGGCGG': 215,
#  'TGGTTGGAGGCCGCGGCGGC': 216,
#  'GGTGATGCTAGAGGTGATGT': 217,
#  'GTGATGCTAGAGGTGATGTT': 218,
#  'TGATGCTAGAGGTGATGTTT': 219,
#  'GATGCTAGAGGTGATGTTTT': 220,
#  'ATGCTAGAGGTGATGTTTTT': 221,
#  'TGCTAGAGGTGATGTTTTTG': 222,
#  'GCTAGAGGTGATGTTTTTGG': 223,
#  'CTAGAGGTGATGTTTTTGGT': 224,
#  'TAGAGGTGATGTTTTTGGTA': 225,
#  'AGAGGTGATGTTTTTGGTAA': 226,
#  'GAGGTGATGTTTTTGGTAAA': 227,
#  'AGGTGATGTTTTTGGTAAAC': 228,
#  'GGTGATGTTTTTGGTAAACA': 229,
#  'GTGATGTTTTTGGTAAACAG': 230,
#  'TGATGTTTTTGGTAAACAGG': 231,
#  'GATGTTTTTGGTAAACAGGC': 232,
#  'ATGTTTTTGGTAAACAGGCG': 233,
#  'TGTTTTTGGTAAACAGGCGG': 234,
#  'GTTTTTGGTAAACAGGCGGG': 235,
#  'TTTTTGGTAAACAGGCGGGG': 236,
#  'TTTTGGTAAACAGGCGGGGT': 237,
#  'TTTGGTAAACAGGCGGGGTA': 238,
#  'TTGGTAAACAGGCGGGGTAA': 239,
#  'TGGTAAACAGGCGGGGTAAG': 240,
#  'GGTAAACAGGCGGGGTAAGA': 241,
#  'GTAAACAGGCGGGGTAAGAT': 242,
#  'TAAACAGGCGGGGTAAGATT': 243,
#  'AAACAGGCGGGGTAAGATTT': 244,
#  'AACAGGCGGGGTAAGATTTG': 245,
#  'ACAGGCGGGGTAAGATTTGC': 246,
#  'CAGGCGGGGTAAGATTTGCC': 247,
#  'ATGTGATGGTGGCCGGGAAG': 248,
#  'TGTGATGGTGGCCGGGAAGA': 249,
#  'GTGATGGTGGCCGGGAAGAG': 250,
#  'TGATGGTGGCCGGGAAGAGG': 251,
#  'GATGGTGGCCGGGAAGAGGC': 252,
#  'ATGGTGGCCGGGAAGAGGCG': 253,
#  'TGGTGGCCGGGAAGAGGCGC': 254,
#  'GGTGGCCGGGAAGAGGCGCT': 255,
#  'GTGGCCGGGAAGAGGCGCTC': 256,
#  'TGGCCGGGAAGAGGCGCTCC': 257,
#  'GGCCGGGAAGAGGCGCTCCT': 258,
#  'GCCGGGAAGAGGCGCTCCTC': 259,
#  'CCGGGAAGAGGCGCTCCTCA': 260,
#  'CGGGAAGAGGCGCTCCTCAC': 261,
#  'GGGAAGAGGCGCTCCTCACC': 262,
#  'GGAAGAGGCGCTCCTCACCT': 263,
#  'GAAGAGGCGCTCCTCACCTG': 264,
#  'AAGAGGCGCTCCTCACCTGT': 265,
#  'AGAGGCGCTCCTCACCTGTC': 266,
#  'GAGGCGCTCCTCACCTGTCT': 267,
#  'AGGCGCTCCTCACCTGTCTC': 268,
#  'GGCGCTCCTCACCTGTCTCT': 269,
#  'GCGCTCCTCACCTGTCTCTT': 270,
#  'CGCTCCTCACCTGTCTCTTA': 271,
#  'GCTCCTCACCTGTCTCTTAT': 272,
#  'CTCCTCACCTGTCTCTTATA': 273,
#  'TCCTCACCTGTCTCTTATAC': 274,
#  'CCTCACCTGTCTCTTATACA': 275,
#  'CTCACCTGTCTCTTATACAC': 276,
#  'TCACCTGTCTCTTATACACA': 277,
#  'CACCTGTCTCTTATACACAT': 278,
#  'ATTATGTATATACATAAAAT': 279,
#  'TTATGTATATACATAAAATA': 280,
#  'TATGTATATACATAAAATAT': 281,
#  'ATGTATATACATAAAATATT': 282,
#  'TGTATATACATAAAATATTT': 283,
#  'GTATATACATAAAATATTTT': 284,
#  'TATATACATAAAATATTTTA': 285,
#  'ATATACATAAAATATTTTAC': 286,
#  'TATACATAAAATATTTTACT': 287,
#  'ATACATAAAATATTTTACTT': 288,
#  'TACATAAAATATTTTACTTT': 289,
#  'ACATAAAATATTTTACTTTA': 290,
#  'CATAAAATATTTTACTTTAT': 291,
#  'ATAAAATATTTTACTTTATA': 292,
#  'TAAAATATTTTACTTTATAA': 293,
#  'AAAATATTTTACTTTATAAA': 294,
#  'AAATATTTTACTTTATAAAA': 295,
#  'AATATTTTACTTTATAAAAT': 296,
#  'ATATTTTACTTTATAAAATA': 297,
#  'TATTTTACTTTATAAAATAG': 298,
#  'ATTTTACTTTATAAAATAGA': 299,
#  'TTTTACTTTATAAAATAGAG': 300,
#  'TTTACTTTATAAAATAGAGT': 301,
#  'TTACTTTATAAAATAGAGTA': 302,
#  'TACTTTATAAAATAGAGTAT': 303,
#  'ACTTTATAAAATAGAGTATT': 304,
#  'CTTTATAAAATAGAGTATTC': 305,
#  'TTTATAAAATAGAGTATTCT': 306,
#  'TTATAAAATAGAGTATTCTC': 307,
#  'TATAAAATAGAGTATTCTCA': 308,
#  'ATAAAATAGAGTATTCTCAG': 309,
#  'GCTTTTGGAACTAATAGAAA': 310,
#  'CTTTTGGAACTAATAGAAAT': 311,
#  'TTTTGGAACTAATAGAAATC': 312,
#  'TTTGGAACTAATAGAAATCT': 313,
#  'TTGGAACTAATAGAAATCTG': 314,
#  'TGGAACTAATAGAAATCTGT': 315,
#  'GGAACTAATAGAAATCTGTT': 316,
#  'GAACTAATAGAAATCTGTTC': 317,
#  'AACTAATAGAAATCTGTTCA': 318,
#  'ACTAATAGAAATCTGTTCAG': 319,
#  'CTAATAGAAATCTGTTCAGC': 320,
#  'TAATAGAAATCTGTTCAGCT': 321,
#  'AATAGAAATCTGTTCAGCTG': 322,
#  'ATAGAAATCTGTTCAGCTGT': 323,
#  'TAGAAATCTGTTCAGCTGTG': 324,
#  'AGAAATCTGTTCAGCTGTGA': 325,
#  'GAAATCTGTTCAGCTGTGAT': 326,
#  'AAATCTGTTCAGCTGTGATT': 327,
#  'AATCTGTTCAGCTGTGATTT': 328,
#  'ATCTGTTCAGCTGTGATTTA': 329,
#  'TCTGTTCAGCTGTGATTTAT': 330,
#  'CTGTTCAGCTGTGATTTATA': 331,
#  'TGTTCAGCTGTGATTTATAT': 332,
#  'GTTCAGCTGTGATTTATATG': 333,
#  'TTCAGCTGTGATTTATATGC': 334,
#  'TCAGCTGTGATTTATATGCA': 335,
#  'CAGCTGTGATTTATATGCAC': 336,
#  'AGCTGTGATTTATATGCACT': 337,
#  'GCTGTGATTTATATGCACTT': 338,
#  'CTGTGATTTATATGCACTTC': 339,
#  'TGTGATTTATATGCACTTCC': 340,
#  'GAATTAGGGAAGTCAGGGTT': 341,
#  'AATTAGGGAAGTCAGGGTTA': 342,
#  'ATTAGGGAAGTCAGGGTTAG': 343,
#  'TTAGGGAAGTCAGGGTTAGG': 344,
#  'TAGGGAAGTCAGGGTTAGGG': 345,
#  'AGGGAAGTCAGGGTTAGGGT': 346,
#  'GGGAAGTCAGGGTTAGGGTG': 347,
#  'GGAAGTCAGGGTTAGGGTGG': 348,
#  'GAAGTCAGGGTTAGGGTGGT': 349,
#  'AAGTCAGGGTTAGGGTGGTT': 350,
#  'AGTCAGGGTTAGGGTGGTTA': 351,
#  'GTCAGGGTTAGGGTGGTTAT': 352,
#  'TCAGGGTTAGGGTGGTTATA': 353,
#  'CAGGGTTAGGGTGGTTATAG': 354,
#  'AGGGTTAGGGTGGTTATAGT': 355,
#  'GGGTTAGGGTGGTTATAGTA': 356,
#  'GGTTAGGGTGGTTATAGTAG': 357,
#  'GTTAGGGTGGTTATAGTAGC': 358,
#  'TTAGGGTGGTTATAGTAGCT': 359,
#  'TAGGGTGGTTATAGTAGCTG': 360,
#  'AGGGTGGTTATAGTAGCTGT': 361,
#  'GGGTGGTTATAGTAGCTGTC': 362,
#  'GGTGGTTATAGTAGCTGTCT': 363,
#  'GTGGTTATAGTAGCTGTCTC': 364,
#  'TGGTTATAGTAGCTGTCTCT': 365,
#  'GGTTATAGTAGCTGTCTCTT': 366,
#  'GTTATAGTAGCTGTCTCTTA': 367,
#  'TTATAGTAGCTGTCTCTTAT': 368,
#  'TATAGTAGCTGTCTCTTATA': 369,
#  'ATAGTAGCTGTCTCTTATAC': 370,
#  'TAGTAGCTGTCTCTTATACA': 371,
#  'GATCTCATCCATCACTGTGA': 372,
#  'ATCTCATCCATCACTGTGAA': 373,
#  'TCTCATCCATCACTGTGAAG': 374,
#  'CTCATCCATCACTGTGAAGT': 375,
#  'TCATCCATCACTGTGAAGTC': 376,
#  'CATCCATCACTGTGAAGTCG': 377,
#  'ATCCATCACTGTGAAGTCGT': 378,
#  'TCCATCACTGTGAAGTCGTG': 379,
#  'CCATCACTGTGAAGTCGTGT': 380,
#  'CATCACTGTGAAGTCGTGTA': 381,
#  'ATCACTGTGAAGTCGTGTAG': 382,
#  'TCACTGTGAAGTCGTGTAGC': 383,
#  'CACTGTGAAGTCGTGTAGCC': 384,
#  'ACTGTGAAGTCGTGTAGCCA': 385,
#  'CTGTGAAGTCGTGTAGCCAC': 386,
#  'TGTGAAGTCGTGTAGCCACT': 387,
#  'GTGAAGTCGTGTAGCCACTC': 388,
#  'TGAAGTCGTGTAGCCACTCC': 389,
#  'GAAGTCGTGTAGCCACTCCA': 390,
#  'AAGTCGTGTAGCCACTCCAC': 391,
#  'AGTCGTGTAGCCACTCCACA': 392,
#  'GTCGTGTAGCCACTCCACAA': 393,
#  'TCGTGTAGCCACTCCACAAA': 394,
#  'CGTGTAGCCACTCCACAAAC': 395,
#  'GTGTAGCCACTCCACAAACG': 396,
#  'TGTAGCCACTCCACAAACGT': 397,
#  'GTAGCCACTCCACAAACGTG': 398,
#  'TAGCCACTCCACAAACGTGT': 399,
#  'AGCCACTCCACAAACGTGTG': 400,
#  'GCCACTCCACAAACGTGTGG': 401,
#  'CCACTCCACAAACGTGTGGC': 402,
#  'GGTCACGCCCCTCGCGGGGC': 403,
#  'GTCACGCCCCTCGCGGGGCT': 404,
#  'TCACGCCCCTCGCGGGGCTA': 405,
#  'CACGCCCCTCGCGGGGCTAG': 406,
#  'ACGCCCCTCGCGGGGCTAGC': 407,
#  'CGCCCCTCGCGGGGCTAGCC': 408,
#  'GCCCCTCGCGGGGCTAGCCC': 409,
#  'CCCCTCGCGGGGCTAGCCCC': 410,
#  'CCCTCGCGGGGCTAGCCCCA': 411,
#  'CCTCGCGGGGCTAGCCCCAG': 412,
#  'CTCGCGGGGCTAGCCCCAGT': 413,
#  'TCGCGGGGCTAGCCCCAGTC': 414,
#  'CGCGGGGCTAGCCCCAGTCC': 415,
#  'GCGGGGCTAGCCCCAGTCCT': 416,
#  'CGGGGCTAGCCCCAGTCCTT': 417,
#  'GGGGCTAGCCCCAGTCCTTT': 418,
#  'GGGCTAGCCCCAGTCCTTTA': 419,
#  'GGCTAGCCCCAGTCCTTTAC': 420,
#  'GCTAGCCCCAGTCCTTTACA': 421,
#  'CTAGCCCCAGTCCTTTACAT': 422,
#  'TAGCCCCAGTCCTTTACATC': 423,
#  'AGCCCCAGTCCTTTACATCT': 424,
#  'GCCCCAGTCCTTTACATCTG': 425,
#  'CCCCAGTCCTTTACATCTGT': 426,
#  'CCCAGTCCTTTACATCTGTC': 427,
#  'CCAGTCCTTTACATCTGTCT': 428,
#  'CAGTCCTTTACATCTGTCTC': 429,
#  'AGTCCTTTACATCTGTCTCT': 430,
#  'GTCCTTTACATCTGTCTCTT': 431,
#  'TCCTTTACATCTGTCTCTTA': 432,
#  'CCTTTACATCTGTCTCTTAT': 433,
#  'GCACCACTGGCACTGGATGC': 434,
#  'CACCACTGGCACTGGATGCT': 435,
#  'ACCACTGGCACTGGATGCTG': 436,
#  'CCACTGGCACTGGATGCTGG': 437,
#  'CACTGGCACTGGATGCTGGA': 438,
#  'ACTGGCACTGGATGCTGGAC': 439,
#  'CTGGCACTGGATGCTGGACC': 440,
#  'TGGCACTGGATGCTGGACCC': 441,
#  'GGCACTGGATGCTGGACCCC': 442,
#  'GCACTGGATGCTGGACCCCT': 443,
#  'CACTGGATGCTGGACCCCTG': 444,
#  'ACTGGATGCTGGACCCCTGC': 445,
#  'CTGGATGCTGGACCCCTGCC': 446,
#  'TGGATGCTGGACCCCTGCCA': 447,
#  'GGATGCTGGACCCCTGCCAG': 448,
#  'GATGCTGGACCCCTGCCAGC': 449,
#  'ATGCTGGACCCCTGCCAGCA': 450,
#  'TGCTGGACCCCTGCCAGCAG': 451,
#  'GCTGGACCCCTGCCAGCAGT': 452,
#  'CTGGACCCCTGCCAGCAGTA': 453,
#  'TGGACCCCTGCCAGCAGTAC': 454,
#  'GGACCCCTGCCAGCAGTACC': 455,
#  'GACCCCTGCCAGCAGTACCT': 456,
#  'ACCCCTGCCAGCAGTACCTT': 457,
#  'CCCCTGCCAGCAGTACCTTT': 458,
#  'CCCTGCCAGCAGTACCTTTG': 459,
#  'CCTGCCAGCAGTACCTTTGC': 460,
#  'CTGCCAGCAGTACCTTTGCT': 461,
#  'TGCCAGCAGTACCTTTGCTA': 462,
#  'GCCAGCAGTACCTTTGCTAC': 463,
#  'CCAGCAGTACCTTTGCTACC': 464,
#  'AAGTAGAACTCAGGATTAAG': 465,
#  'AGTAGAACTCAGGATTAAGA': 466,
#  'GTAGAACTCAGGATTAAGAA': 467,
#  'TAGAACTCAGGATTAAGAAA': 468,
#  'AGAACTCAGGATTAAGAAAC': 469,
#  'GAACTCAGGATTAAGAAACT': 470,
#  'AACTCAGGATTAAGAAACTC': 471,
#  'ACTCAGGATTAAGAAACTCA': 472,
#  'CTCAGGATTAAGAAACTCAC': 473,
#  'TCAGGATTAAGAAACTCACT': 474,
#  'CAGGATTAAGAAACTCACTC': 475,
#  'AGGATTAAGAAACTCACTCA': 476,
#  'GGATTAAGAAACTCACTCAA': 477,
#  'GATTAAGAAACTCACTCAAA': 478,
#  'ATTAAGAAACTCACTCAAAA': 479,
#  'TTAAGAAACTCACTCAAAAC': 480,
#  'TAAGAAACTCACTCAAAACC': 481,
#  'AAGAAACTCACTCAAAACCG': 482,
#  'AGAAACTCACTCAAAACCGC': 483,
#  'GAAACTCACTCAAAACCGCT': 484,
#  'AAACTCACTCAAAACCGCTC': 485,
#  'AACTCACTCAAAACCGCTCA': 486,
#  'ACTCACTCAAAACCGCTCAA': 487,
#  'CTCACTCAAAACCGCTCAAC': 488,
#  'TCACTCAAAACCGCTCAACT': 489,
#  'CACTCAAAACCGCTCAACTG': 490,
#  'ACTCAAAACCGCTCAACTGC': 491,
#  'CTCAAAACCGCTCAACTGCC': 492,
#  'TCAAAACCGCTCAACTGCCT': 493,
#  'CAAAACCGCTCAACTGCCTG': 494,
#  'AAAACCGCTCAACTGCCTGG': 495,
#  'TCTGAGTCCCAGAGGTTACC': 496,
#  'CTGAGTCCCAGAGGTTACCC': 497,
#  'TGAGTCCCAGAGGTTACCCA': 498,
#  'GAGTCCCAGAGGTTACCCAA': 499,
#  'AGTCCCAGAGGTTACCCAAG': 500,
#  'GTCCCAGAGGTTACCCAAGG': 501,
#  'TCCCAGAGGTTACCCAAGGC': 502,
#  'CCCAGAGGTTACCCAAGGCA': 503,
#  'CCAGAGGTTACCCAAGGCAC': 504,
#  'CAGAGGTTACCCAAGGCACC': 505,
#  'AGAGGTTACCCAAGGCACCC': 506,
#  'GAGGTTACCCAAGGCACCCC': 507,
#  'AGGTTACCCAAGGCACCCCT': 508,
#  'GGTTACCCAAGGCACCCCTC': 509,
#  'GTTACCCAAGGCACCCCTCT': 510,
#  'TTACCCAAGGCACCCCTCTG': 511,
#  'TACCCAAGGCACCCCTCTGA': 512,
#  'ACCCAAGGCACCCCTCTGAC': 513,
#  'CCCAAGGCACCCCTCTGACA': 514,
#  'CCAAGGCACCCCTCTGACAC': 515,
#  'CAAGGCACCCCTCTGACACT': 516,
#  'AAGGCACCCCTCTGACACTG': 517,
#  'AGGCACCCCTCTGACACTGT': 518,
#  'GGCACCCCTCTGACACTGTC': 519,
#  'GCACCCCTCTGACACTGTCT': 520,
#  'CACCCCTCTGACACTGTCTC': 521,
#  'ACCCCTCTGACACTGTCTCT': 522,
#  'CCCCTCTGACACTGTCTCTT': 523,
#  'CCCTCTGACACTGTCTCTTA': 524,
#  'CCTCTGACACTGTCTCTTAT': 525,
#  'CTCTGACACTGTCTCTTATA': 526,
#  'CACTTAAACACATCTCTGCC': 527,
#  'ACTTAAACACATCTCTGCCA': 528,
#  'CTTAAACACATCTCTGCCAA': 529,
#  'TTAAACACATCTCTGCCAAA': 530,
#  'TAAACACATCTCTGCCAAAC': 531,
#  'AAACACATCTCTGCCAAACC': 532,
#  'AACACATCTCTGCCAAACCC': 533,
#  'ACACATCTCTGCCAAACCCC': 534,
#  'CACATCTCTGCCAAACCCCA': 535,
#  'ACATCTCTGCCAAACCCCAA': 536,
#  'CATCTCTGCCAAACCCCAAA': 537,
#  'ATCTCTGCCAAACCCCAAAA': 538,
#  'TCTCTGCCAAACCCCAAAAA': 539,
#  'CTCTGCCAAACCCCAAAAAC': 540,
#  'TCTGCCAAACCCCAAAAACA': 541,
#  'CTGCCAAACCCCAAAAACAA': 542,
#  'TGCCAAACCCCAAAAACAAA': 543,
#  'GCCAAACCCCAAAAACAAAG': 544,
#  'CCAAACCCCAAAAACAAAGA': 545,
#  'CAAACCCCAAAAACAAAGAA': 546,
#  'AAACCCCAAAAACAAAGAAC': 547,
#  'AACCCCAAAAACAAAGAACC': 548,
#  'ACCCCAAAAACAAAGAACCC': 549,
#  'CCCCAAAAACAAAGAACCCT': 550,
#  'CCCAAAAACAAAGAACCCTA': 551,
#  'CCAAAAACAAAGAACCCTAA': 552,
#  'CAAAAACAAAGAACCCTAAC': 553,
#  'AAAAACAAAGAACCCTAACA': 554,
#  'AAAACAAAGAACCCTAACAC': 555,
#  'AAACAAAGAACCCTAACACC': 556,
#  'AACAAAGAACCCTAACACCA': 557,
#  'AGACGTAGACACACGAGCAT': 558,
#  'GACGTAGACACACGAGCATA': 559,
#  'ACGTAGACACACGAGCATAT': 560,
#  'CGTAGACACACGAGCATATT': 561,
#  'GTAGACACACGAGCATATTT': 562,
#  'TAGACACACGAGCATATTTC': 563,
#  'AGACACACGAGCATATTTCA': 564,
#  'GACACACGAGCATATTTCAC': 565,
#  'ACACACGAGCATATTTCACC': 566,
#  'CACACGAGCATATTTCACCT': 567,
#  'ACACGAGCATATTTCACCTC': 568,
#  'CACGAGCATATTTCACCTCC': 569,
#  'ACGAGCATATTTCACCTCCG': 570,
#  'CGAGCATATTTCACCTCCGC': 571,
#  'GAGCATATTTCACCTCCGCT': 572,
#  'AGCATATTTCACCTCCGCTA': 573,
#  'GCATATTTCACCTCCGCTAC': 574,
#  'CATATTTCACCTCCGCTACC': 575,
#  'ATATTTCACCTCCGCTACCA': 576,
#  'TATTTCACCTCCGCTACCAT': 577,
#  'ATTTCACCTCCGCTACCATA': 578,
#  'TTTCACCTCCGCTACCATAA': 579,
#  'TTCACCTCCGCTACCATAAT': 580,
#  'TCACCTCCGCTACCATAATC': 581,
#  'CACCTCCGCTACCATAATCA': 582,
#  'ACCTCCGCTACCATAATCAC': 583,
#  'CCTCCGCTACCATAATCACT': 584,
#  'CTCCGCTACCATAATCACTG': 585,
#  'TCCGCTACCATAATCACTGT': 586,
#  'CCGCTACCATAATCACTGTC': 587,
#  'CGCTACCATAATCACTGTCT': 588,
#  'AGTGATGTTTGGATGTAAAG': 589,
#  'GTGATGTTTGGATGTAAAGT': 590,
#  'TGATGTTTGGATGTAAAGTG': 591,
#  'GATGTTTGGATGTAAAGTGA': 592,
#  'ATGTTTGGATGTAAAGTGAA': 593,
#  'TGTTTGGATGTAAAGTGAAA': 594,
#  'GTTTGGATGTAAAGTGAAAT': 595,
#  'TTTGGATGTAAAGTGAAATA': 596,
#  'TTGGATGTAAAGTGAAATAT': 597,
#  'TGGATGTAAAGTGAAATATT': 598,
#  'GGATGTAAAGTGAAATATTA': 599,
#  'GATGTAAAGTGAAATATTAG': 600,
#  'ATGTAAAGTGAAATATTAGT': 601,
#  'TGTAAAGTGAAATATTAGTT': 602,
#  'GTAAAGTGAAATATTAGTTG': 603,
#  'TAAAGTGAAATATTAGTTGG': 604,
#  'AAAGTGAAATATTAGTTGGC': 605,
#  'AAGTGAAATATTAGTTGGCG': 606,
#  'AGTGAAATATTAGTTGGCGG': 607,
#  'GTGAAATATTAGTTGGCGGA': 608,
#  'TGAAATATTAGTTGGCGGAT': 609,
#  'GAAATATTAGTTGGCGGATG': 610,
#  'AAATATTAGTTGGCGGATGA': 611,
#  'AATATTAGTTGGCGGATGAA': 612,
#  'ATATTAGTTGGCGGATGAAG': 613,
#  'TATTAGTTGGCGGATGAAGC': 614,
#  'ATTAGTTGGCGGATGAAGCC': 615,
#  'TTAGTTGGCGGATGAAGCCT': 616,
#  'TAGTTGGCGGATGAAGCCTG': 617,
#  'AGTTGGCGGATGAAGCCTGT': 618,
#  'GTTGGCGGATGAAGCCTGTC': 619,
#  'GCTAGGCTGAACGGCTTCTA': 620,
#  'CTAGGCTGAACGGCTTCTAT': 621,
#  'TAGGCTGAACGGCTTCTATG': 622,
#  'AGGCTGAACGGCTTCTATGG': 623,
#  'GGCTGAACGGCTTCTATGGA': 624,
#  'GCTGAACGGCTTCTATGGAA': 625,
#  'CTGAACGGCTTCTATGGAAT': 626,
#  'TGAACGGCTTCTATGGAATC': 627,
#  'GAACGGCTTCTATGGAATCC': 628,
#  'AACGGCTTCTATGGAATCCT': 629,
#  'ACGGCTTCTATGGAATCCTT': 630,
#  'CGGCTTCTATGGAATCCTTT': 631,
#  'GGCTTCTATGGAATCCTTTG': 632,
#  'GCTTCTATGGAATCCTTTGT': 633,
#  'CTTCTATGGAATCCTTTGTT': 634,
#  'TTCTATGGAATCCTTTGTTT': 635,
#  'TCTATGGAATCCTTTGTTTT': 636,
#  'CTATGGAATCCTTTGTTTTC': 637,
#  'TATGGAATCCTTTGTTTTCC': 638,
#  'ATGGAATCCTTTGTTTTCCC': 639,
#  'TGGAATCCTTTGTTTTCCCA': 640,
#  'GGAATCCTTTGTTTTCCCAG': 641,
#  'GAATCCTTTGTTTTCCCAGG': 642,
#  'AATCCTTTGTTTTCCCAGGG': 643,
#  'ATCCTTTGTTTTCCCAGGGG': 644,
#  'TCCTTTGTTTTCCCAGGGGA': 645,
#  'CCTTTGTTTTCCCAGGGGAG': 646,
#  'CTTTGTTTTCCCAGGGGAGG': 647,
#  'TTTGTTTTCCCAGGGGAGGT': 648,
#  'TTGTTTTCCCAGGGGAGGTA': 649,
#  'TGTTTTCCCAGGGGAGGTAA': 650,
#  'NGGGAAAACACCGACTGTGA': 651,
#  'GGGAAAACACCGACTGTGAT': 652,
#  'GGAAAACACCGACTGTGATA': 653,
#  'GAAAACACCGACTGTGATAA': 654,
#  'AAAACACCGACTGTGATAAA': 655,
#  'AAACACCGACTGTGATAAAC': 656,
#  'AACACCGACTGTGATAAACA': 657,
#  'ACACCGACTGTGATAAACAC': 658,
#  'CACCGACTGTGATAAACACC': 659,
#  'ACCGACTGTGATAAACACCA': 660,
#  'CCGACTGTGATAAACACCAG': 661,
#  'CGACTGTGATAAACACCAGC': 662,
#  'GACTGTGATAAACACCAGCA': 663,
#  'ACTGTGATAAACACCAGCAG': 664,
#  'CTGTGATAAACACCAGCAGG': 665,
#  'TGTGATAAACACCAGCAGGT': 666,
#  'GTGATAAACACCAGCAGGTA': 667,
#  'TGATAAACACCAGCAGGTAG': 668,
#  'GATAAACACCAGCAGGTAGG': 669,
#  'ATAAACACCAGCAGGTAGGC': 670,
#  'TAAACACCAGCAGGTAGGCC': 671,
#  'AAACACCAGCAGGTAGGCCT': 672,
#  'AACACCAGCAGGTAGGCCTG': 673,
#  'ACACCAGCAGGTAGGCCTGT': 674,
#  'CACCAGCAGGTAGGCCTGTC': 675,
#  'ACCAGCAGGTAGGCCTGTCT': 676,
#  'CCAGCAGGTAGGCCTGTCTC': 677,
#  'CAGCAGGTAGGCCTGTCTCT': 678,
#  'AGCAGGTAGGCCTGTCTCTT': 679,
#  'GCAGGTAGGCCTGTCTCTTA': 680,
#  'CAGGTAGGCCTGTCTCTTAT': 681,
#  'NGAGAGAATGAAGAGAAGTA': 682,
#  'GAGAGAATGAAGAGAAGTAA': 683,
#  'AGAGAATGAAGAGAAGTAAG': 684,
#  'GAGAATGAAGAGAAGTAAGC': 685,
#  'AGAATGAAGAGAAGTAAGCC': 686,
#  'GAATGAAGAGAAGTAAGCCG': 687,
#  'AATGAAGAGAAGTAAGCCGA': 688,
#  'ATGAAGAGAAGTAAGCCGAG': 689,
#  'TGAAGAGAAGTAAGCCGAGG': 690,
#  'GAAGAGAAGTAAGCCGAGGG': 691,
#  'AAGAGAAGTAAGCCGAGGGC': 692,
#  'AGAGAAGTAAGCCGAGGGCG': 693,
#  'GAGAAGTAAGCCGAGGGCGT': 694,
#  'AGAAGTAAGCCGAGGGCGTC': 695,
#  'GAAGTAAGCCGAGGGCGTCT': 696,
#  'AAGTAAGCCGAGGGCGTCTT': 697,
#  'AGTAAGCCGAGGGCGTCTTT': 698,
#  'GTAAGCCGAGGGCGTCTTTG': 699,
#  'TAAGCCGAGGGCGTCTTTGA': 700,
#  'AAGCCGAGGGCGTCTTTGAT': 701,
#  'AGCCGAGGGCGTCTTTGATT': 702,
#  'GCCGAGGGCGTCTTTGATTG': 703,
#  'CCGAGGGCGTCTTTGATTGT': 704,
#  'CGAGGGCGTCTTTGATTGTG': 705,
#  'GAGGGCGTCTTTGATTGTGC': 706,
#  'AGGGCGTCTTTGATTGTGCT': 707,
#  'GGGCGTCTTTGATTGTGCTG': 708,
#  'GGCGTCTTTGATTGTGCTGT': 709,
#  'GCGTCTTTGATTGTGCTGTC': 710,
#  'CGTCTTTGATTGTGCTGTCT': 711,
#  'GTCTTTGATTGTGCTGTCTC': 712,
#  'GGAGGGTAGACTGTTCAACC': 713,
#  'GAGGGTAGACTGTTCAACCT': 714,
#  'AGGGTAGACTGTTCAACCTG': 715,
#  'GGGTAGACTGTTCAACCTGT': 716,
#  'GGTAGACTGTTCAACCTGTT': 717,
#  'GTAGACTGTTCAACCTGTTC': 718,
#  'TAGACTGTTCAACCTGTTCC': 719,
#  'AGACTGTTCAACCTGTTCCT': 720,
#  'GACTGTTCAACCTGTTCCTG': 721,
#  'ACTGTTCAACCTGTTCCTGC': 722,
#  'CTGTTCAACCTGTTCCTGCT': 723,
#  'TGTTCAACCTGTTCCTGCTC': 724,
#  'GTTCAACCTGTTCCTGCTCC': 725,
#  'TTCAACCTGTTCCTGCTCCG': 726,
#  'TCAACCTGTTCCTGCTCCGG': 727,
#  'CAACCTGTTCCTGCTCCGGC': 728,
#  'AACCTGTTCCTGCTCCGGCC': 729,
#  'ACCTGTTCCTGCTCCGGCCT': 730,
#  'CCTGTTCCTGCTCCGGCCTC': 731,
#  'CTGTTCCTGCTCCGGCCTCC': 732,
#  'TGTTCCTGCTCCGGCCTCCA': 733,
#  'GTTCCTGCTCCGGCCTCCAC': 734,
#  'TTCCTGCTCCGGCCTCCACT': 735,
#  'TCCTGCTCCGGCCTCCACTA': 736,
#  'CCTGCTCCGGCCTCCACTAT': 737,
#  'CTGCTCCGGCCTCCACTATA': 738,
#  'TGCTCCGGCCTCCACTATAG': 739,
#  'GCTCCGGCCTCCACTATAGC': 740,
#  'CTCCGGCCTCCACTATAGCA': 741,
#  'TCCGGCCTCCACTATAGCAG': 742,
#  'CCGGCCTCCACTATAGCAGA': 743,
#  'TATCGGGCCCATACCCCGAA': 744,
#  'ATCGGGCCCATACCCCGAAA': 745,
#  'TCGGGCCCATACCCCGAAAA': 746,
#  'CGGGCCCATACCCCGAAAAT': 747,
#  'GGGCCCATACCCCGAAAATG': 748,
#  'GGCCCATACCCCGAAAATGT': 749,
#  'GCCCATACCCCGAAAATGTT': 750,
#  'CCCATACCCCGAAAATGTTG': 751,
#  'CCATACCCCGAAAATGTTGG': 752,
#  'CATACCCCGAAAATGTTGGT': 753,
#  'ATACCCCGAAAATGTTGGTT': 754,
#  'TACCCCGAAAATGTTGGTTA': 755,
#  'ACCCCGAAAATGTTGGTTAT': 756,
#  'CCCCGAAAATGTTGGTTATA': 757,
#  'CCCGAAAATGTTGGTTATAC': 758,
#  'CCGAAAATGTTGGTTATACC': 759,
#  'CGAAAATGTTGGTTATACCC': 760,
#  'GAAAATGTTGGTTATACCCT': 761,
#  'AAAATGTTGGTTATACCCTT': 762,
#  'AAATGTTGGTTATACCCTTC': 763,
#  'AATGTTGGTTATACCCTTCC': 764,
#  'ATGTTGGTTATACCCTTCCC': 765,
#  'TGTTGGTTATACCCTTCCCC': 766,
#  'GTTGGTTATACCCTTCCCCT': 767,
#  'TTGGTTATACCCTTCCCCTG': 768,
#  'TGGTTATACCCTTCCCCTGT': 769,
#  'GGTTATACCCTTCCCCTGTC': 770,
#  'GTTATACCCTTCCCCTGTCT': 771,
#  'TTATACCCTTCCCCTGTCTC': 772,
#  'TATACCCTTCCCCTGTCTCT': 773,
#  'ATACCCTTCCCCTGTCTCTT': 774,
#  'GTCAAAGCGAACTACTATAC': 775,
#  'TCAAAGCGAACTACTATACT': 776,
#  'CAAAGCGAACTACTATACTC': 777,
#  'AAAGCGAACTACTATACTCA': 778,
#  'AAGCGAACTACTATACTCAA': 779,
#  'AGCGAACTACTATACTCAAT': 780,
#  'GCGAACTACTATACTCAATT': 781,
#  'CGAACTACTATACTCAATTG': 782,
#  'GAACTACTATACTCAATTGA': 783,
#  'AACTACTATACTCAATTGAT': 784,
#  'ACTACTATACTCAATTGATC': 785,
#  'CTACTATACTCAATTGATCC': 786,
#  'TACTATACTCAATTGATCCA': 787,
#  'ACTATACTCAATTGATCCAA': 788,
#  'CTATACTCAATTGATCCAAT': 789,
#  'TATACTCAATTGATCCAATA': 790,
#  'ATACTCAATTGATCCAATAA': 791,
#  'TACTCAATTGATCCAATAAC': 792,
#  'ACTCAATTGATCCAATAACT': 793,
#  'CTCAATTGATCCAATAACTT': 794,
#  'TCAATTGATCCAATAACTTG': 795,
#  'CAATTGATCCAATAACTTGA': 796,
#  'AATTGATCCAATAACTTGAC': 797,
#  'ATTGATCCAATAACTTGACC': 798,
#  'TTGATCCAATAACTTGACCA': 799,
#  'TGATCCAATAACTTGACCAA': 800,
#  'GATCCAATAACTTGACCAAC': 801,
#  'ATCCAATAACTTGACCAACG': 802,
#  'TCCAATAACTTGACCAACGG': 803,
#  'CCAATAACTTGACCAACGGA': 804,
#  'CAATAACTTGACCAACGGAA': 805,
#  'CTCCTATTTTTCGAATATCT': 806,
#  'TCCTATTTTTCGAATATCTT': 807,
#  'CCTATTTTTCGAATATCTTG': 808,
#  'CTATTTTTCGAATATCTTGT': 809,
#  'TATTTTTCGAATATCTTGTT': 810,
#  'ATTTTTCGAATATCTTGTTC': 811,
#  'TTTTTCGAATATCTTGTTCA': 812,
#  'TTTTCGAATATCTTGTTCAT': 813,
#  'TTTCGAATATCTTGTTCATT': 814,
#  'TTCGAATATCTTGTTCATTG': 815,
#  'TCGAATATCTTGTTCATTGT': 816,
#  'CGAATATCTTGTTCATTGTT': 817,
#  'GAATATCTTGTTCATTGTTA': 818,
#  'AATATCTTGTTCATTGTTAA': 819,
#  'ATATCTTGTTCATTGTTAAG': 820,
#  'TATCTTGTTCATTGTTAAGG': 821,
#  'ATCTTGTTCATTGTTAAGGT': 822,
#  'TCTTGTTCATTGTTAAGGTT': 823,
#  'CTTGTTCATTGTTAAGGTTG': 824,
#  'TTGTTCATTGTTAAGGTTGT': 825,
#  'TGTTCATTGTTAAGGTTGTG': 826,
#  'GTTCATTGTTAAGGTTGTGG': 827,
#  'TTCATTGTTAAGGTTGTGGA': 828,
#  'TCATTGTTAAGGTTGTGGAT': 829,
#  'CATTGTTAAGGTTGTGGATG': 830,
#  'ATTGTTAAGGTTGTGGATGA': 831,
#  'TTGTTAAGGTTGTGGATGAT': 832,
#  'TGTTAAGGTTGTGGATGATG': 833,
#  'GTTAAGGTTGTGGATGATGG': 834,
#  'TTAAGGTTGTGGATGATGGA': 835,
#  'TAAGGTTGTGGATGATGGAT': 836,
#  'ATCAGGCGGCGGCTTCGAAG': 837,
#  'TCAGGCGGCGGCTTCGAAGC': 838,
#  'CAGGCGGCGGCTTCGAAGCC': 839,
#  'AGGCGGCGGCTTCGAAGCCA': 840,
#  'GGCGGCGGCTTCGAAGCCAA': 841,
#  'GCGGCGGCTTCGAAGCCAAA': 842,
#  'CGGCGGCTTCGAAGCCAAAG': 843,
#  'GGCGGCTTCGAAGCCAAAGT': 844,
#  'GCGGCTTCGAAGCCAAAGTG': 845,
#  'CGGCTTCGAAGCCAAAGTGA': 846,
#  'GGCTTCGAAGCCAAAGTGAT': 847,
#  'GCTTCGAAGCCAAAGTGATG': 848,
#  'CTTCGAAGCCAAAGTGATGT': 849,
#  'TTCGAAGCCAAAGTGATGTT': 850,
#  'TCGAAGCCAAAGTGATGTTT': 851,
#  'CGAAGCCAAAGTGATGTTTG': 852,
#  'GAAGCCAAAGTGATGTTTGG': 853,
#  'AAGCCAAAGTGATGTTTGGA': 854,
#  'AGCCAAAGTGATGTTTGGAT': 855,
#  'GCCAAAGTGATGTTTGGATG': 856,
#  'CCAAAGTGATGTTTGGATGT': 857,
#  'CAAAGTGATGTTTGGATGTA': 858,
#  'AAAGTGATGTTTGGATGTAA': 859,
#  'AAGTGATGTTTGGATGTAAA': 860,
#  'CTCATAGGGGACAGACATTA': 861,
#  'TCATAGGGGACAGACATTAG': 862,
#  'CATAGGGGACAGACATTAGC': 863,
#  'ATAGGGGACAGACATTAGCA': 864,
#  'TAGGGGACAGACATTAGCAA': 865,
#  'AGGGGACAGACATTAGCAAA': 866,
#  'GGGGACAGACATTAGCAAAA': 867,
#  'GGGACAGACATTAGCAAAAA': 868,
#  'GGACAGACATTAGCAAAAAT': 869,
#  'GACAGACATTAGCAAAAATC': 870,
#  'ACAGACATTAGCAAAAATCA': 871,
#  'CAGACATTAGCAAAAATCAA': 872,
#  'AGACATTAGCAAAAATCAAG': 873,
#  'GACATTAGCAAAAATCAAGG': 874,
#  'ACATTAGCAAAAATCAAGGT': 875,
#  'CATTAGCAAAAATCAAGGTA': 876,
#  'ATTAGCAAAAATCAAGGTAT': 877,
#  'TTAGCAAAAATCAAGGTATG': 878,
#  'TAGCAAAAATCAAGGTATGG': 879,
#  'AGCAAAAATCAAGGTATGGC': 880,
#  'GCAAAAATCAAGGTATGGCC': 881,
#  'CAAAAATCAAGGTATGGCCT': 882,
#  'AAAAATCAAGGTATGGCCTG': 883,
#  'AAAATCAAGGTATGGCCTGT': 884,
#  'AAATCAAGGTATGGCCTGTC': 885,
#  'AATCAAGGTATGGCCTGTCG': 886,
#  'ATCAAGGTATGGCCTGTCGT': 887,
#  'TCAAGGTATGGCCTGTCGTG': 888,
#  'CAAGGTATGGCCTGTCGTGT': 889,
#  'AAGGTATGGCCTGTCGTGTC': 890,
#  'AGGTATGGCCTGTCGTGTCA': 891,
#  'AGCTATCACCAGGCTCGGTA': 892,
#  'GCTATCACCAGGCTCGGTAG': 893,
#  'CTATCACCAGGCTCGGTAGG': 894,
#  'TATCACCAGGCTCGGTAGGT': 895,
#  'ATCACCAGGCTCGGTAGGTT': 896,
#  'TCACCAGGCTCGGTAGGTTT': 897,
#  'CACCAGGCTCGGTAGGTTTG': 898,
#  'ACCAGGCTCGGTAGGTTTGT': 899,
#  'CCAGGCTCGGTAGGTTTGTC': 900,
#  'CAGGCTCGGTAGGTTTGTCG': 901,
#  'AGGCTCGGTAGGTTTGTCGC': 902,
#  'GGCTCGGTAGGTTTGTCGCC': 903,
#  'GCTCGGTAGGTTTGTCGCCT': 904,
#  'CTCGGTAGGTTTGTCGCCTC': 905,
#  'TCGGTAGGTTTGTCGCCTCT': 906,
#  'CGGTAGGTTTGTCGCCTCTA': 907,
#  'GGTAGGTTTGTCGCCTCTAC': 908,
#  'GTAGGTTTGTCGCCTCTACC': 909,
#  'TAGGTTTGTCGCCTCTACCT': 910,
#  'AGGTTTGTCGCCTCTACCTA': 911,
#  'GGTTTGTCGCCTCTACCTAT': 912,
#  'GTTTGTCGCCTCTACCTATA': 913,
#  'TTTGTCGCCTCTACCTATAA': 914,
#  'TTGTCGCCTCTACCTATAAA': 915,
#  'TGTCGCCTCTACCTATAAAT': 916,
#  'GTCGCCTCTACCTATAAATC': 917,
#  'TCGCCTCTACCTATAAATCT': 918,
#  'CGCCTCTACCTATAAATCTT': 919,
#  'GCCTCTACCTATAAATCTTC': 920,
#  'CCTCTACCTATAAATCTTCC': 921,
#  'CTCTACCTATAAATCTTCCC': 922,
#  'AAGTTGAGATGATATCATTT': 923,
#  'AGTTGAGATGATATCATTTA': 924,
#  'GTTGAGATGATATCATTTAC': 925,
#  'TTGAGATGATATCATTTACG': 926,
#  'TGAGATGATATCATTTACGG': 927,
#  'GAGATGATATCATTTACGGG': 928,
#  'AGATGATATCATTTACGGGG': 929,
#  'GATGATATCATTTACGGGGG': 930,
#  'ATGATATCATTTACGGGGGA': 931,
#  'TGATATCATTTACGGGGGAA': 932,
#  'GATATCATTTACGGGGGAAG': 933,
#  'ATATCATTTACGGGGGAAGG': 934,
#  'TATCATTTACGGGGGAAGGC': 935,
#  'ATCATTTACGGGGGAAGGCG': 936,
#  'TCATTTACGGGGGAAGGCGC': 937,
#  'CATTTACGGGGGAAGGCGCT': 938,
#  'ATTTACGGGGGAAGGCGCTT': 939,
#  'TTTACGGGGGAAGGCGCTTT': 940,
#  'TTACGGGGGAAGGCGCTTTG': 941,
#  'TACGGGGGAAGGCGCTTTGT': 942,
#  'ACGGGGGAAGGCGCTTTGTG': 943,
#  'CGGGGGAAGGCGCTTTGTGA': 944,
#  'GGGGGAAGGCGCTTTGTGAA': 945,
#  'GGGGAAGGCGCTTTGTGAAG': 946,
#  'GGGAAGGCGCTTTGTGAAGT': 947,
#  'GGAAGGCGCTTTGTGAAGTA': 948,
#  'GAAGGCGCTTTGTGAAGTAG': 949,
#  'AAGGCGCTTTGTGAAGTAGG': 950,
#  'AGGCGCTTTGTGAAGTAGGC': 951,
#  'GGCGCTTTGTGAAGTAGGCC': 952,
#  'GCGCTTTGTGAAGTAGGCCT': 953,
#  'CATGAGTGCAAGACGTCTTG': 954,
#  'ATGAGTGCAAGACGTCTTGT': 955,
#  'TGAGTGCAAGACGTCTTGTG': 956,
#  'GAGTGCAAGACGTCTTGTGA': 957,
#  'AGTGCAAGACGTCTTGTGAT': 958,
#  'GTGCAAGACGTCTTGTGATG': 959,
#  'TGCAAGACGTCTTGTGATGT': 960,
#  'GCAAGACGTCTTGTGATGTA': 961,
#  'CAAGACGTCTTGTGATGTAA': 962,
#  'AAGACGTCTTGTGATGTAAT': 963,
#  'AGACGTCTTGTGATGTAATT': 964,
#  'GACGTCTTGTGATGTAATTA': 965,
#  'ACGTCTTGTGATGTAATTAT': 966,
#  'CGTCTTGTGATGTAATTATT': 967,
#  'GTCTTGTGATGTAATTATTA': 968,
#  'TCTTGTGATGTAATTATTAT': 969,
#  'CTTGTGATGTAATTATTATA': 970,
#  'TTGTGATGTAATTATTATAC': 971,
#  'TGTGATGTAATTATTATACG': 972,
#  'GTGATGTAATTATTATACGA': 973,
#  'TGATGTAATTATTATACGAA': 974,
#  'GATGTAATTATTATACGAAT': 975,
#  'ATGTAATTATTATACGAATG': 976,
#  'TGTAATTATTATACGAATGG': 977,
#  'GTAATTATTATACGAATGGG': 978,
#  'TAATTATTATACGAATGGGG': 979,
#  'AATTATTATACGAATGGGGG': 980,
#  'ATTATTATACGAATGGGGGC': 981,
#  'TTATTATACGAATGGGGGCT': 982,
#  'TATTATACGAATGGGGGCTT': 983,
#  'ATTATACGAATGGGGGCTTC': 984,
#  'CCCCAGCTCCTGTGGCAGGG': 985,
#  'CCCAGCTCCTGTGGCAGGGC': 986,
#  'CCAGCTCCTGTGGCAGGGCC': 987,
#  'CAGCTCCTGTGGCAGGGCCA': 988,
#  'AGCTCCTGTGGCAGGGCCAG': 989,
#  'GCTCCTGTGGCAGGGCCAGG': 990,
#  'CTCCTGTGGCAGGGCCAGGT': 991,
#  'TCCTGTGGCAGGGCCAGGTA': 992,
#  'CCTGTGGCAGGGCCAGGTAC': 993,
#  'CTGTGGCAGGGCCAGGTACT': 994,
#  'TGTGGCAGGGCCAGGTACTC': 995,
#  'GTGGCAGGGCCAGGTACTCC': 996,
#  'TGGCAGGGCCAGGTACTCCC': 997,
#  'GGCAGGGCCAGGTACTCCCA': 998,
#  'GCAGGGCCAGGTACTCCCAG': 999,
#  ...}
